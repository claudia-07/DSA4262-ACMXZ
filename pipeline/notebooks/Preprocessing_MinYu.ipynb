# %% [markdown]
# # Importing Libraries

# %%
# %cd ..
# Out:
# c:\Users\lowmi\OneDrive\Desktop\Uni\DSA4262\DSA4262-ACMXZ\pipeline

# %%
import pandas as pd
import numpy as np
import os

from preprocessing import (Preprocessing, Modelling)
from utilities import get_percent

# %% [markdown]
# # Preparing Data

# %% [markdown]
# ### Loading parquets

# %%
info_data_path = "../data/raw_data/data.info"
with open(info_data_path, 'r') as f:
    info = f.read().splitlines()
data_df = pd.read_parquet("../data/raw_data/data.parquet")

# %% [markdown]
# ### Reading files and merging dfs

# %%
info_list = [info[i].split(",") for i in range(len(info))]
info_df = pd.DataFrame(info_list[1:]) 
info_df.columns = info_list[0]
info_df.to_parquet("info.parquet")

# %%
df = data_df.merge(info_df, how = "left", left_on = ["transcript", "position"], 
                    right_on = ["transcript_id", "transcript_position"])

# %%
# df_1 = pd.DataFrame(data_1.groupby(['transcript', 'position', 'nucleotides', 'label'], as_index=False)
#                             .agg({'dwelling_time': [get_percent(25), get_percent(50), get_percent(75), np.mean], 
#                                     'std': [get_percent(25), get_percent(50), get_percent(75), np.mean], 
#                                     'mean': [get_percent(25), get_percent(50), get_percent(75), np.mean]}))

# %% [markdown]
# # Preprocessing

# %% [markdown]
# id_cols = ['transcript', 'position']
# <br>
# label encoding = ['nucleotides']
# <br>
# normalization = ['dwelling_time', 'std', 'mean']

# %%
df_pre = Modelling(df)

# %%
df_pre.model_features_and_clean()
# Out:
#                transcript position nucleotides          gene_id  \
# 185       ENST00000000233      244       AGACC  ENSG00000004059
# 186       ENST00000000233      244       AGACC  ENSG00000004059
# 187       ENST00000000233      244       AGACC  ENSG00000004059
# 188       ENST00000000233      244       AGACC  ENSG00000004059
# 189       ENST00000000233      244       AGACC  ENSG00000004059
# ...                   ...      ...         ...              ...
# 33081261  ENST00000641834     1693       TGACA  ENSG00000167747
# 33081262  ENST00000641834     1693       TGACA  ENSG00000167747
# 33081263  ENST00000641834     1693       TGACA  ENSG00000167747
# 33081264  ENST00000641834     1693       TGACA  ENSG00000167747
# 33081265  ENST00000641834     1693       TGACA  ENSG00000167747
#
#           dwelling_time    std   mean label
# 185             0.01770  10.40  122.0     0
# 186             0.00844   4.67  126.0     0
# 187             0.01360  12.00  124.0     0
# 188             0.00830   5.01  130.0     0
# 189             0.00266   3.94  129.0     0
# ...                 ...    ...    ...   ...
# 33081261        0.00564  10.20  116.0     0
# 33081262        0.00598  12.30  110.0     0
# 33081263        0.00398   6.58  113.0     0
# 33081264        0.00913  10.40  108.0     0
# 33081265        0.00303   9.98  118.0     0
#
# [11027106 rows x 8 columns]

# %%
df_pre.feature_eng()
# Out:
#                 gene_id       transcript position nucleotides label  \
# 0       ENSG00000000003  ENST00000373020     1006       AGACC     0
# 1       ENSG00000000003  ENST00000373020     1013       AAACT     0
# 2       ENSG00000000003  ENST00000373020     1149       AAACA     0
# 3       ENSG00000000003  ENST00000373020      512       TAACT     0
# 4       ENSG00000000003  ENST00000373020      689       AAACA     0
# ...                 ...              ...      ...         ...   ...
# 121833  ENSG00000284707  ENST00000641784     3122       TGACC     1
# 121834  ENSG00000284707  ENST00000641784     3142       TGACC     0
# 121835  ENSG00000284707  ENST00000641784     3224       GGACT     1
# 121836  ENSG00000284707  ENST00000641784     3243       GAACA     0
# 121837  ENSG00000284707  ENST00000641784     3266       TAACT     0
#
#         dwelling_time_25  dwelling_time_50  dwelling_time_75  \
# 0               0.005980          0.009090          0.014900
# 1               0.003320          0.005305          0.007763
# 2               0.004958          0.006885          0.010733
# 3               0.003980          0.007735          0.013375
# 4               0.003650          0.006420          0.008960
# ...                  ...               ...               ...
# 121833          0.004432          0.007165          0.009483
# 121834          0.004320          0.006100          0.009630
# 121835          0.004882          0.006310          0.011525
# 121836          0.005145          0.006580          0.009157
# 121837          0.004432          0.005785          0.007955
#
#         dwelling_time_mean  std_25  std_50   std_75  std_mean  mean_25  \
# 0                 0.011677  4.3000   5.600   7.5800  6.000000   125.00
# 1                 0.006050  3.8850   4.415   4.8200  4.091500   100.00
# 2                 0.008051  1.9875   2.570   2.9875  2.652227    96.80
# 3                 0.011177  2.0800   2.375   2.7300  2.496500    97.05
# 4                 0.007332  1.9600   2.430   2.9100  2.551905    96.20
# ...                    ...     ...     ...      ...       ...      ...
# 121833            0.007801  4.3575   6.365   8.4275  6.736167   116.00
# 121834            0.007614  6.9200   8.880  10.6000  8.877377   116.00
# 121835            0.008247  3.0200   4.420   5.6125  4.507167   122.00
# 121836            0.007648  2.2575   2.675   3.1225  2.998125    95.35
# 121837            0.006831  1.8825   2.170   2.4625  2.194032    98.90
#
#         mean_50  mean_75   mean_mean
# 0        127.00   128.00  127.000000
# 1        102.00   105.00  102.675000
# 2         98.50   100.75   99.081818
# 3         98.05    99.05   97.965000
# 4         98.70    99.70   97.928571
# ...         ...      ...         ...
# 121833   117.00   120.25  118.050000
# 121834   120.00   123.00  119.721311
# 121835   125.00   127.25  124.466667
# 121836    97.60    98.85   97.346875
# 121837    99.75   101.00   99.730645
#
# [121838 rows x 17 columns]

# %%
df_all_features = df_pre.df

# %%
df_train, df_test, df_val, X_train, y_train, X_val, y_val, X_test, y_test, df_val_id, list_train = df_pre.split_stratified_into_train_val_test(random_state=42)
# Out:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# train target percentage: 0.049255441008018326
# test target percentage: 0.06377880184331797
# val target percentage: 0.07129746472410232
# train data shape: (107379, 14)
# validation data shape: (17434, 14)
# test data shape: (16275, 14)
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_pre.X_train
# Out:
#        nucleotides  dwelling_time_25  dwelling_time_50  dwelling_time_75  \
# 0            AGACC          0.005980          0.009090          0.014900
# 1            AAACT          0.003320          0.005305          0.007763
# 2            AAACA          0.004958          0.006885          0.010733
# 3            TAACT          0.003980          0.007735          0.013375
# 4            AAACA          0.003650          0.006420          0.008960
# ...            ...               ...               ...               ...
# 107374       TGACC          0.004432          0.007165          0.009483
# 107375       TGACC          0.004320          0.006100          0.009630
# 107376       GGACT          0.004882          0.006310          0.011525
# 107377       GAACA          0.005145          0.006580          0.009157
# 107378       TAACT          0.004432          0.005785          0.007955
#
#         dwelling_time_mean  std_25  std_50   std_75  std_mean  mean_25  \
# 0                 0.011677  4.3000   5.600   7.5800  6.000000   125.00
# 1                 0.006050  3.8850   4.415   4.8200  4.091500   100.00
# 2                 0.008051  1.9875   2.570   2.9875  2.652227    96.80
# 3                 0.011177  2.0800   2.375   2.7300  2.496500    97.05
# 4                 0.007332  1.9600   2.430   2.9100  2.551905    96.20
# ...                    ...     ...     ...      ...       ...      ...
# 107374            0.007801  4.3575   6.365   8.4275  6.736167   116.00
# 107375            0.007614  6.9200   8.880  10.6000  8.877377   116.00
# 107376            0.008247  3.0200   4.420   5.6125  4.507167   122.00
# 107377            0.007648  2.2575   2.675   3.1225  2.998125    95.35
# 107378            0.006831  1.8825   2.170   2.4625  2.194032    98.90
#
#         mean_50  mean_75   mean_mean
# 0        127.00   128.00  127.000000
# 1        102.00   105.00  102.675000
# 2         98.50   100.75   99.081818
# 3         98.05    99.05   97.965000
# 4         98.70    99.70   97.928571
# ...         ...      ...         ...
# 107374   117.00   120.25  118.050000
# 107375   120.00   123.00  119.721311
# 107376   125.00   127.25  124.466667
# 107377    97.60    98.85   97.346875
# 107378    99.75   101.00   99.730645
#
# [107379 rows x 13 columns]

# %%
X_train_oversampled = df_pre.oversample_undersample()

# %%
X_train_oversampled
# Out:
#       nucleotides  dwelling_time_25  dwelling_time_50  dwelling_time_75  \
# 0           GGACT          0.006310          0.009230          0.013300
# 1           GAACA          0.004298          0.006310          0.009673
# 2           AAACT          0.004092          0.006475          0.009960
# 3           GAACT          0.003910          0.005980          0.009630
# 4           AAACA          0.004650          0.005640          0.006805
# ...           ...               ...               ...               ...
# 51562       GAACA          0.004125          0.005921          0.009163
# 51563       GGACT          0.004852          0.007296          0.010985
# 51564       TGACA          0.004046          0.005856          0.008492
# 51565       GAACT          0.004046          0.005340          0.007102
# 51566       GGACA          0.004052          0.007667          0.011640
#
#        dwelling_time_mean    std_25    std_50    std_75  std_mean     mean_25  \
# 0                0.010990  4.800000  6.160000  8.280000  6.639487  118.000000
# 1                0.007737  2.687500  3.375000  4.952500  4.138917   91.100000
# 2                0.007692  2.447500  3.015000  3.842500  3.269531  102.000000
# 3                0.007635  2.990000  3.480000  4.290000  4.013333   98.100000
# 4                0.006277  2.430000  2.920000  3.425000  3.024444   94.800000
# ...                   ...       ...       ...       ...       ...         ...
# 51562            0.007203  2.437136  2.841286  3.526068  3.191178   93.865048
# 51563            0.008554  4.339364  6.179448  8.604927  6.646295  120.996059
# 51564            0.006910  5.227768  6.854815  8.788404  7.095782  115.000000
# 51565            0.005812  2.503244  2.953576  3.821851  3.372486   98.592722
# 51566            0.009199  4.449837  5.999572  7.460480  6.296453  110.281919
#
#           mean_50     mean_75   mean_mean
# 0      120.000000  122.000000  119.555556
# 1       93.100000   95.225000   93.633333
# 2      105.000000  107.000000  104.375000
# 3       99.600000  101.500000  100.089308
# 4       96.300000   98.000000   96.637037
# ...           ...         ...         ...
# 51562   94.977913   96.444175   95.211601
# 51563  123.000000  124.984234  122.610429
# 51564  117.000000  121.000000  117.901847
# 51565  100.000000  102.000000  100.442201
# 51566  115.000000  119.718081  115.004690
#
# [51567 rows x 13 columns]

# %%
X_train_oversampled
# Out:
#       nucleotides  dwelling_time_25  dwelling_time_50  dwelling_time_75  \
# 0           GGACT          0.006310          0.009230          0.013300
# 1           GAACA          0.004298          0.006310          0.009673
# 2           AAACT          0.004092          0.006475          0.009960
# 3           GAACT          0.003910          0.005980          0.009630
# 4           AAACA          0.004650          0.005640          0.006805
# ...           ...               ...               ...               ...
# 51562       GAACA          0.004125          0.005921          0.009163
# 51563       GGACT          0.004852          0.007296          0.010985
# 51564       TGACA          0.004046          0.005856          0.008492
# 51565       GAACT          0.004046          0.005340          0.007102
# 51566       GGACA          0.004052          0.007667          0.011640
#
#        dwelling_time_mean    std_25    std_50    std_75  std_mean     mean_25  \
# 0                0.010990  4.800000  6.160000  8.280000  6.639487  118.000000
# 1                0.007737  2.687500  3.375000  4.952500  4.138917   91.100000
# 2                0.007692  2.447500  3.015000  3.842500  3.269531  102.000000
# 3                0.007635  2.990000  3.480000  4.290000  4.013333   98.100000
# 4                0.006277  2.430000  2.920000  3.425000  3.024444   94.800000
# ...                   ...       ...       ...       ...       ...         ...
# 51562            0.007203  2.437136  2.841286  3.526068  3.191178   93.865048
# 51563            0.008554  4.339364  6.179448  8.604927  6.646295  120.996059
# 51564            0.006910  5.227768  6.854815  8.788404  7.095782  115.000000
# 51565            0.005812  2.503244  2.953576  3.821851  3.372486   98.592722
# 51566            0.009199  4.449837  5.999572  7.460480  6.296453  110.281919
#
#           mean_50     mean_75   mean_mean
# 0      120.000000  122.000000  119.555556
# 1       93.100000   95.225000   93.633333
# 2      105.000000  107.000000  104.375000
# 3       99.600000  101.500000  100.089308
# 4       96.300000   98.000000   96.637037
# ...           ...         ...         ...
# 51562   94.977913   96.444175   95.211601
# 51563  123.000000  124.984234  122.610429
# 51564  117.000000  121.000000  117.901847
# 51565  100.000000  102.000000  100.442201
# 51566  115.000000  119.718081  115.004690
#
# [51567 rows x 13 columns]

# %%
X_train_enc, pipe = df_pre.encoding_train()
# Out:
# columns after preprocessing : ['dwelling_time_25', 'dwelling_time_50', 'dwelling_time_75', 'dwelling_time_mean', 'std_25', 'std_50', 'std_75', 'std_mean', 'mean_25', 'mean_50', 'mean_75', 'mean_mean', 'nucleotides']
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
X_test_enc = df_pre.encoding_test_val()
# Out:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
X_val_enc = df_pre.encoding_test_val(test = False)
# Out:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_val = df_pre.modelling_lightgbm()
# Out:
# Start Time           2022-10-12 00:44:57.509031
#   0%|          | 0/5 [00:00<?, ?trial/s, best loss=?]
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#  20%|██        | 1/5 [00:00<00:00,  5.87trial/s, best loss=?]
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
#
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\lowmi\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\lowmi\anaconda3\lib\site-packages\lightgbm\sklearn.py", line 890, in fit
#     super().fit(X, _y, sample_weight=sample_weight, init_score=init_score, eval_set=valid_sets,
#   File "c:\Users\lowmi\anaconda3\lib\site-packages\lightgbm\sklearn.py", line 683, in fit
#     self._Booster = train(params, train_set,
#   File "c:\Users\lowmi\anaconda3\lib\site-packages\lightgbm\engine.py", line 228, in train
#     booster = Booster(params=params, train_set=train_set)
#   File "c:\Users\lowmi\anaconda3\lib\site-packages\lightgbm\basic.py", line 2229, in __init__
#     train_set.construct()
#   File "c:\Users\lowmi\anaconda3\lib\site-packages\lightgbm\basic.py", line 1468, in construct
#     self._lazy_init(self.data, label=self.label,
#   File "c:\Users\lowmi\anaconda3\lib\site-packages\lightgbm\basic.py", line 1209, in _lazy_init
#     data, feature_name, categorical_feature, self.pandas_categorical = _data_from_pandas(data,
#   File "c:\Users\lowmi\anaconda3\lib\site-packages\lightgbm\basic.py", line 537, in _data_from_pandas
#     raise ValueError("DataFrame.dtypes for data must be int, float or bool.\n"
# ValueError: DataFrame.dtypes for data must be int, float or bool.
# Did not expect the data types in the following fields: dwelling_time_25, dwelling_time_50, dwelling_time_75, dwelling_time_mean, std_25, std_50, std_75, std_mean, mean_25, mean_50, mean_75, mean_mean, nucleotides
#
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#  40%|████      | 2/5 [00:00<00:00,  6.42trial/s, best loss=?]
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
#
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\lowmi\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\lowmi\anaconda3\lib\site-packages\lightgbm\sklearn.py", line 890, in fit
#     super().fit(X, _y, sample_weight=sample_weight, init_score=init_score, eval_set=valid_sets,
#   File "c:\Users\lowmi\anaconda3\lib\site-packages\lightgbm\sklearn.py", line 683, in fit
#     self._Booster = train(params, train_set,
#   File "c:\Users\lowmi\anaconda3\lib\site-packages\lightgbm\engine.py", line 228, in train
#     booster = Booster(params=params, train_set=train_set)
#   File "c:\Users\lowmi\anaconda3\lib\site-packages\lightgbm\basic.py", line 2229, in __init__
#     train_set.construct()
#   File "c:\Users\lowmi\anaconda3\lib\site-packages\lightgbm\basic.py", line 1468, in construct
#     self._lazy_init(self.data, label=self.label,
#   File "c:\Users\lowmi\anaconda3\lib\site-packages\lightgbm\basic.py", line 1209, in _lazy_init
#     data, feature_name, categorical_feature, self.pandas_categorical = _data_from_pandas(data,
#   File "c:\Users\lowmi\anaconda3\lib\site-packages\lightgbm\basic.py", line 537, in _data_from_pandas
#     raise ValueError("DataFrame.dtypes for data must be int, float or bool.\n"
# ValueError: DataFrame.dtypes for data must be int, float or bool.
# Did not expect the data types in the following fields: dwelling_time_25, dwelling_time_50, dwelling_time_75, dwelling_time_mean, std_25, std_50, std_75, std_mean, mean_25, mean_50, mean_75, mean_mean, nucleotides
#
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#  80%|████████  | 4/5 [00:00<00:00,  7.01trial/s, best loss=?]
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\lowmi\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\lowmi\anaconda3\lib\site-packages\lightgbm\sklearn.py", line 890, in fit
#     super().fit(X, _y, sample_weight=sample_weight, init_score=init_score, eval_set=valid_sets,
#   File "c:\Users\lowmi\anaconda3\lib\site-packages\lightgbm\sklearn.py", line 683, in fit
#     self._Booster = train(params, train_set,
#   File "c:\Users\lowmi\anaconda3\lib\site-packages\lightgbm\engine.py", line 228, in train
#     booster = Booster(params=params, train_set=train_set)
#   File "c:\Users\lowmi\anaconda3\lib\site-packages\lightgbm\basic.py", line 2229, in __init__
#     train_set.construct()
#   File "c:\Users\lowmi\anaconda3\lib\site-packages\lightgbm\basic.py", line 1468, in construct
#     self._lazy_init(self.data, label=self.label,
#   File "c:\Users\lowmi\anaconda3\lib\site-packages\lightgbm\basic.py", line 1209, in _lazy_init
#     data, feature_name, categorical_feature, self.pandas_categorical = _data_from_pandas(data,
#   File "c:\Users\lowmi\anaconda3\lib\site-packages\lightgbm\basic.py", line 537, in _data_from_pandas
#     raise ValueError("DataFrame.dtypes for data must be int, float or bool.\n"
# ValueError: DataFrame.dtypes for data must be int, float or bool.
# Did not expect the data types in the following fields: dwelling_time_25, dwelling_time_50, dwelling_time_75, dwelling_time_mean, std_25, std_50, std_75, std_mean, mean_25, mean_50, mean_75, mean_mean, nucleotides
#
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
#
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\lowmi\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\lowmi\anaconda3\lib\site-packages\lightgbm\sklearn.py", line 890, in fit
#     super().fit(X, _y, sample_weight=sample_weight, init_score=init_score, eval_set=valid_sets,
#   File "c:\Users\lowmi\anaconda3\lib\site-packages\lightgbm\sklearn.py", line 683, in fit
#     self._Booster = train(params, train_set,
#   File "c:\Users\lowmi\anaconda3\lib\site-packages\lightgbm\engine.py", line 228, in train
#     booster = Booster(params=params, train_set=train_set)
#   File "c:\Users\lowmi\anaconda3\lib\site-packages\lightgbm\basic.py", line 2229, in __init__
#     train_set.construct()
#   File "c:\Users\lowmi\anaconda3\lib\site-packages\lightgbm\basic.py", line 1468, in construct
#     self._lazy_init(self.data, label=self.label,
#   File "c:\Users\lowmi\anaconda3\lib\site-packages\lightgbm\basic.py", line 1209, in _lazy_init
#     data, feature_name, categorical_feature, self.pandas_categorical = _data_from_pandas(data,
#   File "c:\Users\lowmi\anaconda3\lib\site-packages\lightgbm\basic.py", line 537, in _data_from_pandas
#     raise ValueError("DataFrame.dtypes for data must be int, float or bool.\n"
# ValueError: DataFrame.dtypes for data must be int, float or bool.
# Did not expect the data types in the following fields: dwelling_time_25, dwelling_time_50, dwelling_time_75, dwelling_time_mean, std_25, std_50, std_75, std_mean, mean_25, mean_50, mean_75, mean_mean, nucleotides
#
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# 100%|██████████| 5/5 [00:00<00:00,  6.86trial/s, best loss=?]
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
#
# 5 fits failed out of a total of 5.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\lowmi\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\lowmi\anaconda3\lib\site-packages\lightgbm\sklearn.py", line 890, in fit
#     super().fit(X, _y, sample_weight=sample_weight, init_score=init_score, eval_set=valid_sets,
#   File "c:\Users\lowmi\anaconda3\lib\site-packages\lightgbm\sklearn.py", line 683, in fit
#     self._Booster = train(params, train_set,
#   File "c:\Users\lowmi\anaconda3\lib\site-packages\lightgbm\engine.py", line 228, in train
#     booster = Booster(params=params, train_set=train_set)
#   File "c:\Users\lowmi\anaconda3\lib\site-packages\lightgbm\basic.py", line 2229, in __init__
#     train_set.construct()
#   File "c:\Users\lowmi\anaconda3\lib\site-packages\lightgbm\basic.py", line 1468, in construct
#     self._lazy_init(self.data, label=self.label,
#   File "c:\Users\lowmi\anaconda3\lib\site-packages\lightgbm\basic.py", line 1209, in _lazy_init
#     data, feature_name, categorical_feature, self.pandas_categorical = _data_from_pandas(data,
#   File "c:\Users\lowmi\anaconda3\lib\site-packages\lightgbm\basic.py", line 537, in _data_from_pandas
#     raise ValueError("DataFrame.dtypes for data must be int, float or bool.\n"
# ValueError: DataFrame.dtypes for data must be int, float or bool.
# Did not expect the data types in the following fields: dwelling_time_25, dwelling_time_50, dwelling_time_75, dwelling_time_mean, std_25, std_50, std_75, std_mean, mean_25, mean_50, mean_75, mean_mean, nucleotides
# ---------------------------------------------------------------------------
# AllTrialsFailed                           Traceback (most recent call last)
# c:\Users\lowmi\OneDrive\Desktop\Uni\DSA4262\DSA4262-ACMXZ\pipeline\notebooks\Preprocessing_MinYu.ipynb Cell 25 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/lowmi/OneDrive/Desktop/Uni/DSA4262/DSA4262-ACMXZ/pipeline/notebooks/Preprocessing_MinYu.ipynb#X36sZmlsZQ%3D%3D?line=0'>1</a> df_val = df_pre.modelling_lightgbm()
#
# File c:\Users\lowmi\OneDrive\Desktop\Uni\DSA4262\DSA4262-ACMXZ\pipeline\preprocessing\modelling.py:80, in Modelling.modelling_lightgbm(self)
#      77 print("%-20s %s" % ("Start Time", start_time))
#      79 # search space
# ---> 80 best=fmin(fn = my_lgbm, # function to optimize
#      81         space = lgbm_tune_kwargs,
#      82         algo = tpe.suggest, # optimization algorithm, hyperotp will select its parameters automatically
#      83         max_evals = max_n_iter, # maximum number of iterations
#      84         trials = trials, # logging
#      85         rstate = np.random.default_rng(seed)  # fixing random state for reproducibility
#      86         )
#      88 print('-'*50)
#      89 print('The best params:')
#
# File c:\Users\lowmi\anaconda3\lib\site-packages\hyperopt\fmin.py:540, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     537     fn = __objective_fmin_wrapper(fn)
#     539 if allow_trials_fmin and hasattr(trials, "fmin"):
# --> 540     return trials.fmin(
#     541         fn,
#     542         space,
#     543         algo=algo,
#     544         max_evals=max_evals,
#     545         timeout=timeout,
#     546         loss_threshold=loss_threshold,
#     547         max_queue_len=max_queue_len,
#     548         rstate=rstate,
#     549         pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     550         verbose=verbose,
#     551         catch_eval_exceptions=catch_eval_exceptions,
#     552         return_argmin=return_argmin,
#     553         show_progressbar=show_progressbar,
#     554         early_stop_fn=early_stop_fn,
#     555         trials_save_file=trials_save_file,
#     556     )
#     558 if trials is None:
#     559     if os.path.exists(trials_save_file):
#
# File c:\Users\lowmi\anaconda3\lib\site-packages\hyperopt\base.py:671, in Trials.fmin(self, fn, space, algo, max_evals, timeout, loss_threshold, max_queue_len, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin, show_progressbar, early_stop_fn, trials_save_file)
#     666 # -- Stop-gap implementation!
#     667 #    fmin should have been a Trials method in the first place
#     668 #    but for now it's still sitting in another file.
#     669 from .fmin import fmin
# --> 671 return fmin(
#     672     fn,
#     673     space,
#     674     algo=algo,
#     675     max_evals=max_evals,
#     676     timeout=timeout,
#     677     loss_threshold=loss_threshold,
#     678     trials=self,
#     679     rstate=rstate,
#     680     verbose=verbose,
#     681     max_queue_len=max_queue_len,
#     682     allow_trials_fmin=False,  # -- prevent recursion
#     683     pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     684     catch_eval_exceptions=catch_eval_exceptions,
#     685     return_argmin=return_argmin,
#     686     show_progressbar=show_progressbar,
#     687     early_stop_fn=early_stop_fn,
#     688     trials_save_file=trials_save_file,
#     689 )
#
# File c:\Users\lowmi\anaconda3\lib\site-packages\hyperopt\fmin.py:593, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     589     if len(trials.trials) == 0:
#     590         raise Exception(
#     591             "There are no evaluation tasks, cannot return argmin of task losses."
#     592         )
# --> 593     return trials.argmin
#     594 if len(trials) > 0:
#     595     # Only if there are some successful trail runs, return the best point in
#     596     # the evaluation space
#     597     return space_eval(space, trials.argmin)
#
# File c:\Users\lowmi\anaconda3\lib\site-packages\hyperopt\base.py:620, in Trials.argmin(self)
#     618 @property
#     619 def argmin(self):
# --> 620     best_trial = self.best_trial
#     621     vals = best_trial["misc"]["vals"]
#     622     # unpack the one-element lists to values
#     623     # and skip over the 0-element lists
#
# File c:\Users\lowmi\anaconda3\lib\site-packages\hyperopt\base.py:611, in Trials.best_trial(self)
#     605 candidates = [
#     606     t
#     607     for t in self.trials
#     608     if t["result"]["status"] == STATUS_OK and not np.isnan(t["result"]["loss"])
#     609 ]
#     610 if not candidates:
# --> 611     raise AllTrialsFailed
#     612 losses = [float(t["result"]["loss"]) for t in candidates]
#     613 if len(losses) == 0:
#
# AllTrialsFailed:

# %% [markdown]
# # Exporting Datasets

# %%
# %cd ../data/preprocessed_data
# Out:
# c:\Users\lowmi\OneDrive\Desktop\Uni\DSA4262\DSA4262-ACMXZ\data\preprocessed_data

# %%
df_all_features.to_parquet("df_all_features.parquet") # df containing all features, before splitting/encoding
df_train.to_parquet("df_train.parquet") # df containing all features, after splitting, before encoding
df_test.to_parquet("df_test.parquet") # df containing all features, after splitting, before encoding
df_val.to_parquet("df_val.parquet") # df containing all features, after splitting, before encoding
X_train.to_parquet("X_train.parquet") # df containing all features, after splitting, before encoding
y_train.to_parquet("y_train.parquet") # df containing all features, after splitting, before encoding
X_val.to_parquet("X_val.parquet") # df containing all features, after splitting, before encoding
y_val.to_parquet("y_val.parquet") # df containing all features, after splitting, before encoding
X_test.to_parquet("X_test.parquet") # df containing all features, after splitting, before encoding
y_test.to_parquet("y_test.parquet") # df containing all features, after splitting, before encoding
df_val_id.to_parquet("df_val_id.parquet") # df containing all features, after splitting, before encoding
#X_train_enc.to_parquet("X_train_enc.parquet") # df containing all features, after encoding, before oversampling
X_test_enc.to_parquet("X_test_enc.parquet") 
X_val_enc.to_parquet("X_val_enc.parquet")
# Out:
# ---------------------------------------------------------------------------
# ArrowInvalid                              Traceback (most recent call last)
# c:\Users\lowmi\OneDrive\Desktop\Uni\DSA4262\DSA4262-ACMXZ\pipeline\notebooks\Preprocessing_MinYu.ipynb Cell 28 in <cell line: 12>()
#      <a href='vscode-notebook-cell:/c%3A/Users/lowmi/OneDrive/Desktop/Uni/DSA4262/DSA4262-ACMXZ/pipeline/notebooks/Preprocessing_MinYu.ipynb#X33sZmlsZQ%3D%3D?line=9'>10</a> y_test.to_parquet("y_test.parquet") # df containing all features, after splitting, before encoding
#      <a href='vscode-notebook-cell:/c%3A/Users/lowmi/OneDrive/Desktop/Uni/DSA4262/DSA4262-ACMXZ/pipeline/notebooks/Preprocessing_MinYu.ipynb#X33sZmlsZQ%3D%3D?line=10'>11</a> df_val_id.to_parquet("df_val_id.parquet") # df containing all features, after splitting, before encoding
# ---> <a href='vscode-notebook-cell:/c%3A/Users/lowmi/OneDrive/Desktop/Uni/DSA4262/DSA4262-ACMXZ/pipeline/notebooks/Preprocessing_MinYu.ipynb#X33sZmlsZQ%3D%3D?line=11'>12</a> X_train_enc.to_parquet("X_train_enc.parquet") # df containing all features, after encoding, before oversampling
#      <a href='vscode-notebook-cell:/c%3A/Users/lowmi/OneDrive/Desktop/Uni/DSA4262/DSA4262-ACMXZ/pipeline/notebooks/Preprocessing_MinYu.ipynb#X33sZmlsZQ%3D%3D?line=12'>13</a> X_test_enc.to_parquet("X_test_enc.parquet")
#      <a href='vscode-notebook-cell:/c%3A/Users/lowmi/OneDrive/Desktop/Uni/DSA4262/DSA4262-ACMXZ/pipeline/notebooks/Preprocessing_MinYu.ipynb#X33sZmlsZQ%3D%3D?line=13'>14</a> X_val_enc.to_parquet()
#
# File c:\Users\lowmi\anaconda3\lib\site-packages\pandas\util\_decorators.py:207, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     205     else:
#     206         kwargs[new_arg_name] = new_arg_value
# --> 207 return func(*args, **kwargs)
#
# File c:\Users\lowmi\anaconda3\lib\site-packages\pandas\core\frame.py:2835, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, **kwargs)
#    2749 """
#    2750 Write a DataFrame to the binary parquet format.
#    2751
#    (...)
#    2831 >>> content = f.read()
#    2832 """
#    2833 from pandas.io.parquet import to_parquet
# -> 2835 return to_parquet(
#    2836     self,
#    2837     path,
#    2838     engine,
#    2839     compression=compression,
#    2840     index=index,
#    2841     partition_cols=partition_cols,
#    2842     storage_options=storage_options,
#    2843     **kwargs,
#    2844 )
#
# File c:\Users\lowmi\anaconda3\lib\site-packages\pandas\io\parquet.py:420, in to_parquet(df, path, engine, compression, index, storage_options, partition_cols, **kwargs)
#     416 impl = get_engine(engine)
#     418 path_or_buf: FilePath | WriteBuffer[bytes] = io.BytesIO() if path is None else path
# --> 420 impl.write(
#     421     df,
#     422     path_or_buf,
#     423     compression=compression,
#     424     index=index,
#     425     partition_cols=partition_cols,
#     426     storage_options=storage_options,
#     427     **kwargs,
#     428 )
#     430 if path is None:
#     431     assert isinstance(path_or_buf, io.BytesIO)
#
# File c:\Users\lowmi\anaconda3\lib\site-packages\pandas\io\parquet.py:174, in PyArrowImpl.write(self, df, path, compression, index, storage_options, partition_cols, **kwargs)
#     171 if index is not None:
#     172     from_pandas_kwargs["preserve_index"] = index
# --> 174 table = self.api.Table.from_pandas(df, **from_pandas_kwargs)
#     176 path_or_handle, handles, kwargs["filesystem"] = _get_path_or_handle(
#     177     path,
#     178     kwargs.pop("filesystem", None),
#    (...)
#     181     is_dir=partition_cols is not None,
#     182 )
#     183 try:
#
# File c:\Users\lowmi\anaconda3\lib\site-packages\pyarrow\table.pxi:3480, in pyarrow.lib.Table.from_pandas()
#
# File c:\Users\lowmi\anaconda3\lib\site-packages\pyarrow\pandas_compat.py:622, in dataframe_to_arrays(df, schema, preserve_index, nthreads, columns, safe)
#     620     for i, maybe_fut in enumerate(arrays):
#     621         if isinstance(maybe_fut, futures.Future):
# --> 622             arrays[i] = maybe_fut.result()
#     624 types = [x.type for x in arrays]
#     626 if schema is None:
#
# File c:\Users\lowmi\anaconda3\lib\concurrent\futures\_base.py:439, in Future.result(self, timeout)
#     437     raise CancelledError()
#     438 elif self._state == FINISHED:
# --> 439     return self.__get_result()
#     441 self._condition.wait(timeout)
#     443 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File c:\Users\lowmi\anaconda3\lib\concurrent\futures\_base.py:391, in Future.__get_result(self)
#     389 if self._exception:
#     390     try:
# --> 391         raise self._exception
#     392     finally:
#     393         # Break a reference cycle with the exception in self._exception
#     394         self = None
#
# File c:\Users\lowmi\anaconda3\lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File c:\Users\lowmi\anaconda3\lib\site-packages\pyarrow\pandas_compat.py:596, in dataframe_to_arrays.<locals>.convert_column(col, field)
#     591 except (pa.ArrowInvalid,
#     592         pa.ArrowNotImplementedError,
#     593         pa.ArrowTypeError) as e:
#     594     e.args += ("Conversion failed for column {!s} with type {!s}"
#     595                .format(col.name, col.dtype),)
# --> 596     raise e
#     597 if not field_nullable and result.null_count > 0:
#     598     raise ValueError("Field {} was non-nullable but pandas column "
#     599                      "had {} null values".format(str(field),
#     600                                                  result.null_count))
#
# File c:\Users\lowmi\anaconda3\lib\site-packages\pyarrow\pandas_compat.py:590, in dataframe_to_arrays.<locals>.convert_column(col, field)
#     587     type_ = field.type
#     589 try:
# --> 590     result = pa.array(col, type=type_, from_pandas=True, safe=safe)
#     591 except (pa.ArrowInvalid,
#     592         pa.ArrowNotImplementedError,
#     593         pa.ArrowTypeError) as e:
#     594     e.args += ("Conversion failed for column {!s} with type {!s}"
#     595                .format(col.name, col.dtype),)
#
# File c:\Users\lowmi\anaconda3\lib\site-packages\pyarrow\array.pxi:313, in pyarrow.lib.array()
#
# File c:\Users\lowmi\anaconda3\lib\site-packages\pyarrow\array.pxi:83, in pyarrow.lib._ndarray_to_array()
#
# File c:\Users\lowmi\anaconda3\lib\site-packages\pyarrow\error.pxi:100, in pyarrow.lib.check_status()
#
# ArrowInvalid: ('Can only convert 1-dimensional array values', 'Conversion failed for column nucleotides with type object')
